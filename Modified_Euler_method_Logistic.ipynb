# %%
#function
# %matplotlib notebook
import math
import matplotlib.pyplot as plt
f=lambda x:(10**6)/(1+9*math.exp(19.8-x/100))
dy=lambda x,y: (10**-2*y)-(10**-8*y**2)
#initialization
xi=1980;xf=2020;h=5
n=int((xf-xi)/h)
x=1980;y=10**5
print('x   \t\t y \t\t f(x) \t\t |f(x)-y| ')
print('%f \t %f \t %f \t %f'%(x,y,f(x),abs(f(x)-y)))
x_plot=[];y_euler=[];y_exact=[]
#Eulers Method
for i in range(1,n+1):
     x_plot.append(x);y_euler.append(y);y_exact.append(f(x))
     y= y+(h/2)*(dy(x,y)+dy(x+h,y+h*dy(x,y)))
     x=x+h
     print('%f \t %f \t %f \t %f'%(x,y,f(x),abs(f(x)-y)))
x_plot.append(x);y_euler.append(y);y_exact.append(f(x))
plt.plot(x_plot,y_euler,'ko-',x_plot,y_exact,'r--')
plt.legend(['Modified Euler','Exact solution'])
plt.xlabel('Time (Year)');plt.ylabel('Population')
plt.grid()
plt.savefig('Modifi_eu_logis.png')
safa_modi_eu=y_euler
# Out:
# x   		 y 		 f(x) 		 |f(x)-y|
# 1980.000000 	 100000.000000 	 100000.000000 	 0.000000
# 1985.000000 	 104589.493750 	 104590.860827 	 1.367077
# 1990.000000 	 109364.048186 	 109366.870391 	 2.822205
# 1995.000000 	 114328.756202 	 114333.122838 	 4.366635
# 2000.000000 	 119488.630417 	 119494.631711 	 6.001294
# 2005.000000 	 124848.578509 	 124856.305256 	 7.726747
# 2010.000000 	 130413.376863 	 130422.920029 	 9.543167
# 2015.000000 	 136187.642559 	 136199.092863 	 11.450304
# 2020.000000 	 142175.803763 	 142189.251215 	 13.447453
# <img src="data:image/png;base64,..." width="640">

# %%
safa_modi_eu
# Out:
# [100000,
#  104589.49375,
#  109364.04818620131,
#  114328.7562022048,
#  119488.63041733202,
#  124848.57850943187,
#  130413.37686270023,
#  136187.64255904016,
#  142175.80376270015]
