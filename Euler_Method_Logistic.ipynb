# %%
#function
# %matplotlib notebook
import math
import matplotlib.pyplot as plt
f=lambda x:(10**6)/(1+9*math.exp(19.8-x/100))
dy=lambda x,y: (10**-2*y)-(10**-8*y**2)
#initialization
xi=1980;xf=2020;h=5
n=int((xf-xi)/h)
x=1980;y=10**5
print('x   \t\t y \t\t f(x) \t\t |f(x)-y| ')
print('%f \t %f \t %f \t  %f'%(x,y,f(x),abs(f(x)-y)))
x_plot=[];y_euler=[];y_exact=[]
#Eulers Method
for i in range(1,n+1):
     x_plot.append(x);y_euler.append(y);y_exact.append(f(x))
     y= y+h*dy(x,y)
     x=x+h
     print('%f \t %f \t %f \t %f'%(x,y,f(x),abs(f(x)-y)))
x_plot.append(x);y_euler.append(y);y_exact.append(f(x))
plt.plot(x_plot,y_euler,'bo-',x_plot,y_exact,'ro-')
plt.legend(['Numerical Solution(Euler Method)','Exact Solution'])
plt.xlabel('Time (Year)');plt.ylabel('Population')
plt.grid()
plt.savefig('Euler_logistic.png')

safa_euler=y_euler
# Out:
# x   		 y 		 f(x) 		 |f(x)-y|
# 1980.000000 	 100000.000000 	 100000.000000 	  0.000000
# 1985.000000 	 104500.000000 	 104590.860827 	 90.860827
# 1990.000000 	 109178.987500 	 109366.870391 	 187.882891
# 1995.000000 	 114041.934309 	 114333.122838 	 291.188528
# 2000.000000 	 119093.752886 	 119494.631711 	 400.878826
# 2005.000000 	 124339.274431 	 124856.305256 	 517.030825
# 2010.000000 	 129783.225395 	 130422.920029 	 639.694635
# 2015.000000 	 135430.202385 	 136199.092863 	 768.890478
# 2020.000000 	 141284.645518 	 142189.251215 	 904.605697
# <img src="data:image/png;base64,..." width="640">

# %%
safa_euler
# Out:
# [100000,
#  104500.0,
#  109178.9875,
#  114041.93430942374,
#  119093.75288584319,
#  124339.27443131364,
#  129783.22539457404,
#  135430.2023846118,
#  141284.64551794555]
