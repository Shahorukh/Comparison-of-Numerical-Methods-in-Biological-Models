# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
safa=[1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020]

# %%
safa_exact=[100000.0,
 104590.86082705096,
 109366.87039095681,
 114333.12283751133,
 119494.63171139327,
 124856.3052561278,
 130422.92002939398,
 136199.09286266714,
 142189.25121543964]

# %%
safa_euler=[100000,
 104500.0,
 109178.9875,
 114041.93430942374,
 119093.75288584319,
 124339.27443131364,
 129783.22539457404,
 135430.2023846118,
 141284.64551794555]

# %%
safa_modi_eu=[100000,
 104589.49375,
 109364.04818620131,
 114328.7562022048,
 119488.63041733202,
 124848.57850943187,
 130413.37686270023,
 136187.64255904016,
 142175.80376270015]

# %%
safa_rk=[100000,
 104590.86068951228,
 109366.87010847774,
 114333.12240274294,
 119494.63111707976,
 124856.30449514731,
 130422.91909480204,
 136199.09174774177,
 142189.2499137263]

# %%
plt.plot(safa,safa_exact,'ro-',safa,safa_euler,'b',safa,safa_modi_eu,'k',safa,safa_rk,'g--')
plt.xlabel('Time (year)');plt.ylabel('Population')
plt.legend(["Exact Solution","Euler Method","Modified Euler Method","RK4 Method"])
plt.title('Numerical Solution vs Exact Solution')
plt.grid()
plt.savefig('All_graph_logisitc.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
