# %%
#function
# %matplotlib notebook
import math
import matplotlib.pyplot as plt
f=lambda x:10**7*math.exp(-3*x/50)
dy=lambda x,y: -0.06*y
#initialization
xi=0;xf=7;h=1
n=int((xf-xi)/h)
x=0.0;y=10**7
print('x   \t\t\t y \t\t\t f(x) \t\t |f(x)-y| ')
print('%f \t %f \t %f \t %f'%(x,y,f(x),abs(f(x)-y)))
x_plot=[];y_euler=[];y_exact=[]
#Eulers Method
for i in range(1,n+1):
     x_plot.append(x);y_euler.append(y);y_exact.append(f(x))
     y= y+h*dy(x,y)
     x=x+h
     print('%f \t %f \t %f \t %f'%(x,y,f(x),abs(f(x)-y)))
x_plot.append(x);y_euler.append(y);y_exact.append(f(x))
plt.plot(x_plot,y_euler,'bo-',x_plot,y_exact,'ro-')
plt.legend(['Numerical Solution(Euler Method)','Exact solution'])
plt.xlabel('Time (Week)');plt.ylabel('Concentration of Bacteria (parts/m^3)')
plt.grid()
#plt.title('Euler Method vs Exact Solution')
safa_euler=y_euler
plt.savefig('Euler_Bact.png')
# Out:
# x   			 y 			 f(x) 		 |f(x)-y|
# 0.000000 	 10000000.000000 	 10000000.000000 	 0.000000
# 1.000000 	 9400000.000000 	 9417645.335842 	 17645.335842
# 2.000000 	 8836000.000000 	 8869204.367172 	 33204.367172
# 3.000000 	 8305840.000000 	 8352702.114113 	 46862.114113
# 4.000000 	 7807489.600000 	 7866278.610666 	 58789.010666
# 5.000000 	 7339040.224000 	 7408182.206817 	 69141.982817
# 6.000000 	 6898697.810560 	 6976763.260710 	 78065.450150
# 7.000000 	 6484775.941926 	 6570468.198151 	 85692.256224
# <img src="data:image/png;base64,..." width="640">

# %%
safa_euler
# Out:
# [10000000,
#  9400000.0,
#  8836000.0,
#  8305840.0,
#  7807489.6,
#  7339040.223999999,
#  6898697.810559999,
#  6484775.941926399]
