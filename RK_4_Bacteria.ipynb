# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import math
#function
dy=lambda x,y: -0.06*y
f=lambda x:10**7*math.exp(-3*x/50)
#initialization
xi=0;xf=7;h=1
n =int((xf-xi)/h)
x=0;y=10**7
#Visualization of code initialization
print('x   \t\t\t y \t\t\t f(x) \t\t |f(x)-y|')
print('%f \t %f \t %f \t %f'%(x,y,f(x),abs(f(x)-y)))
x_plot=[];y_rk4=[];y_exact=[]
#RK4 Method
for i in range(1,n+1):
    x_plot.append(x);y_rk4.append(y);y_exact.append(f(x))
    #rk4 method
    k1=h*dy(x,y)
    k2=h*dy(x+h/2,y+k1*0.5)
    k3=h*dy(x+h/2,y+k2*0.5)
    k4=h*dy(x+h,y+k3)
    #Calculate new y estimation
    y=y + 1 / 6 * (k1+2*k2+2*k3+k4)
    #Increase x by step size to calculate next y extimate
    x=x+h
    print('%f \t %f \t %f \t %f'%(x,y,f(x),abs(f(x)-y)))
    
#visulation code
x_plot.append(x);y_rk4.append(y);y_exact.append(f(x))
plt.plot(x_plot,y_rk4,'go-',x_plot,y_exact,'r--')
plt.xlabel('Time (Week)');plt.ylabel('Concentration of Bacteria (parts/m^3)')
plt.legend(["Numerical Solution(RK4 Method)","Exact solution"])
safa_rk=y_rk4
safa_exact=y_exact
plt.grid()
plt.show()
plt.savefig('Rk4_Bact.png')
# Out:
# x   			 y 			 f(x) 		 |f(x)-y|
# 0.000000 	 10000000.000000 	 10000000.000000 	 0.000000
# 1.000000 	 9417645.400000 	 9417645.335842 	 0.064158
# 2.000000 	 8869204.488014 	 8869204.367172 	 0.120843
# 3.000000 	 8352702.284821 	 8352702.114113 	 0.170708
# 4.000000 	 7866278.825021 	 7866278.610666 	 0.214355
# 5.000000 	 7408182.459158 	 7408182.206817 	 0.252340
# 6.000000 	 6976763.545885 	 6976763.260710 	 0.285174
# 7.000000 	 6570468.511479 	 6570468.198151 	 0.313328
# <img src="data:image/png;base64,..." width="640">

# %%
safa_rk
# Out:
# [10000000,
#  9417645.4,
#  8869204.488014117,
#  8352702.28482055,
#  7866278.8250209745,
#  7408182.459157619,
#  6976763.545884644,
#  6570468.511478821]

# %%
safa_exact
# Out:
# [10000000.0,
#  9417645.335842486,
#  8869204.367171574,
#  8352702.11411272,
#  7866278.610665535,
#  7408182.206817179,
#  6976763.26071031,
#  6570468.198150568]
