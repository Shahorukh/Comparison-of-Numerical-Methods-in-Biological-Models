# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
t=np.arange(0,8,1)
y=10**7*np.exp(-3*t/50)
plt.plot(t,y,'ro-')
plt.legend(['Exact Solution'])
plt.xlabel('Time (Week)');plt.ylabel('Concentration of Bacteria (parts/m^3)')
plt.grid()
plt.show()
plt.savefig('Exact_Bact.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
