# %%
import matplotlib.pyplot as plt
import math
# %matplotlib notebook
#function
f=lambda x:(10**6)/(1+9*math.exp(19.8-x/100))
dy=lambda x,y: (10**-2*y)-(10**-8*y**2)
#initialization
xi=1980;xf=2020;h=5
n =int((xf-xi)/h)
x=1980;y=10**5
#Visualization of code initialization
print('x   \t\t\t y \t f(x) \t\t |f(x)-y|')
print('%f \t %f \t %f \t %f'%(x,y,f(x),abs(f(x)-y)))
x_plot=[];y_rk4=[];y_exact=[]
#RK4 Method
for i in range(1,n+1):
    x_plot.append(x);y_rk4.append(y);y_exact.append(f(x))
    #rk4 method
    k1=h*dy(x,y)
    k2=h*dy(x+h*0.5,y+k1*0.5)
    k3=h*dy(x+h*0.5,y+k2*0.5)
    k4=h*dy(x+h,y+k3)
    #Calculate new y estimation
    y=y + 1 / 6 * (k1+2*k2+2*k3+k4)
    #Increase x by step size to calculate next y extimate
    x=x+h
    print('%f \t %f \t %f \t %f'%(x,y,f(x),abs(f(x)-y)))
    
#visulation code
x_plot.append(x);y_rk4.append(y);y_exact.append(f(x))
plt.plot(x_plot,y_rk4,'go-',x_plot,y_exact,'r--')
plt.xlabel('Time (Year)');plt.ylabel('Population')
plt.legend(["Numerical solution(Rk4 Method)","Exact Solution"])
plt.grid()
plt.savefig('Rk_logistic.png')
safa=x_plot
safa_exact=y_exact
safa_rk=y_rk4
# Out:
# x   			 y 	 f(x) 		 |f(x)-y|
# 1980.000000 	 100000.000000 	 100000.000000 	 0.000000
# 1985.000000 	 104590.860690 	 104590.860827 	 0.000138
# 1990.000000 	 109366.870108 	 109366.870391 	 0.000282
# 1995.000000 	 114333.122403 	 114333.122838 	 0.000435
# 2000.000000 	 119494.631117 	 119494.631711 	 0.000594
# 2005.000000 	 124856.304495 	 124856.305256 	 0.000761
# 2010.000000 	 130422.919095 	 130422.920029 	 0.000935
# 2015.000000 	 136199.091748 	 136199.092863 	 0.001115
# 2020.000000 	 142189.249914 	 142189.251215 	 0.001302
# <img src="data:image/png;base64,..." width="640">

# %%
safa
# Out:
# [1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020]

# %%
safa_exact
# Out:
# [100000.0,
#  104590.86082705096,
#  109366.87039095681,
#  114333.12283751133,
#  119494.63171139327,
#  124856.3052561278,
#  130422.92002939398,
#  136199.09286266714,
#  142189.25121543964]

# %%
safa_rk
# Out:
# [100000,
#  104590.86068951228,
#  109366.87010847774,
#  114333.12240274294,
#  119494.63111707976,
#  124856.30449514731,
#  130422.91909480204,
#  136199.09174774177,
#  142189.2499137263]
